# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatimanridegreeclg/Mini-project-/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
a1
# Out:
# [91,
#  58,
#  13,
#  64,
#  92,
#  11,
#  32,
#  63,
#  71,
#  27,
#  71,
#  0,
#  52,
#  7,
#  18,
#  62,
#  65,
#  55,
#  100,
#  14,
#  12,
#  7,
#  48,
#  4,
#  44,
#  78,
#  67,
#  53,
#  91,
#  7,
#  83,
#  5,
#  44,
#  65,
#  3,
#  78,
#  91,
#  47,
#  51,
#  15,
#  65,
#  67,
#  66,
#  49,
#  59,
#  48,
#  96,
#  23,
#  97,
#  44,
#  84,
#  50,
#  49,
#  6,
#  0,
#  85,
#  78,
#  92,
#  87,
#  22,
#  71,
#  86,
#  29,
#  81,
#  63,
#  65,
#  95,
#  46,
#  83,
#  28,
#  55,
#  37,
#  21,
#  16,
#  15,
#  71,
#  17,
#  43,
#  60,
#  6,
#  87,
#  23,
#  96,
#  64,
#  42,
#  2,
#  85,
#  82,
#  37,
#  11,
#  61,
#  25,
#  9,
#  5,
#  11,
#  14,
#  67,
#  94,
#  8,
#  96,
#  59,
#  22,
#  7,
#  54,
#  59,
#  34,
#  1,
#  33,
#  23,
#  39,
#  21,
#  74,
#  47,
#  11,
#  88,
#  19,
#  86,
#  72,
#  15,
#  29,
#  47,
#  45,
#  65,
#  5,
#  71,
#  71,
#  10,
#  92,
#  47,
#  90,
#  28,
#  29,
#  59,
#  32,
#  27,
#  100,
#  81,
#  35,
#  35,
#  58,
#  85,
#  12,
#  39,
#  4,
#  3,
# ...

# %%
df = {
  'grade':a1,
  'weight':a2,
  'friends':a3,
  'cousins':a4,
  'projects':a5,
}

# %%
df
# Out:
# {'grade': [91,
#   58,
#   13,
#   64,
#   92,
#   11,
#   32,
#   63,
#   71,
#   27,
#   71,
#   0,
#   52,
#   7,
#   18,
#   62,
#   65,
#   55,
#   100,
#   14,
#   12,
#   7,
#   48,
#   4,
#   44,
#   78,
#   67,
#   53,
#   91,
#   7,
#   83,
#   5,
#   44,
#   65,
#   3,
#   78,
#   91,
#   47,
#   51,
#   15,
#   65,
#   67,
#   66,
#   49,
#   59,
#   48,
#   96,
#   23,
#   97,
#   44,
#   84,
#   50,
#   49,
#   6,
#   0,
#   85,
#   78,
#   92,
#   87,
#   22,
#   71,
#   86,
#   29,
#   81,
#   63,
#   65,
#   95,
#   46,
#   83,
#   28,
#   55,
#   37,
#   21,
#   16,
#   15,
#   71,
#   17,
#   43,
#   60,
#   6,
#   87,
#   23,
#   96,
#   64,
#   42,
#   2,
#   85,
#   82,
#   37,
#   11,
#   61,
#   25,
#   9,
#   5,
#   11,
#   14,
#   67,
#   94,
#   8,
#   96,
#   59,
#   22,
#   7,
#   54,
#   59,
#   34,
#   1,
#   33,
#   23,
#   39,
#   21,
#   74,
#   47,
#   11,
#   88,
#   19,
#   86,
#   72,
#   15,
#   29,
#   47,
#   45,
#   65,
#   5,
#   71,
# ...

# %%
import pandas as pd

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       91      70       11        6        50
# 1       58      55       18        8        47
# 2       13      53       12        8        77
# 3       64      51       13        9        43
# 4       92      54       12        8        63
# ..     ...     ...      ...      ...       ...
# 995      8      61       15       10        54
# 996      8      55       15        6        35
# 997      3      56       15       10        79
# 998     82      65       10        7        25
# 999     97      53       19        5        59
#
# [1000 rows x 5 columns]

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       91      70       11        6        50
# 1       58      55       18        8        47
# 2       13      53       12        8        77
# 3       64      51       13        9        43
# 4       92      54       12        8        63
# ..     ...     ...      ...      ...       ...
# 995      8      61       15       10        54
# 996      8      55       15        6        35
# 997      3      56       15       10        79
# 998     82      65       10        7        25
# 999     97      53       19        5        59
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade      weight      friends      cousins   projects
# count  1000.000000  1000.00000  1000.000000  1000.000000  1000.0000
# mean     48.352000    60.26500    15.055000     7.412000    49.3930
# std      29.732072     6.28142     3.182154     1.717325    17.2795
# min       0.000000    50.00000    10.000000     5.000000    20.0000
# 25%      22.000000    55.00000    12.000000     6.000000    34.0000
# 50%      48.000000    60.00000    15.000000     7.000000    49.0000
# 75%      75.000000    66.00000    18.000000     9.000000    65.0000
# max     100.000000    70.00000    20.000000    10.000000    80.0000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      91
# 1      58
# 2      13
# 3      64
# 4      92
#        ..
# 995     8
# 996     8
# 997     3
# 998    82
# 999    97
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15=df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 1       58      55       18        8        47
# 6       32      55       18        8        33
# 10      71      56       16        5        28
# 11       0      57       17        9        50
# 15      62      68       18       10        72
# ..     ...     ...      ...      ...       ...
# 985     79      62       17        5        37
# 987      2      61       19        5        31
# 992     65      64       16        5        36
# 993     20      70       17       10        65
# 999     97      53       19        5        59
#
# [471 rows x 5 columns]

# %%
df1[friend15].describe()
# Out:
#             grade      weight     friends     cousins    projects
# count  471.000000  471.000000  471.000000  471.000000  471.000000
# mean    47.484076   60.150743   18.019108    7.341826   49.736730
# std     30.390285    6.216707    1.376728    1.669479   17.508986
# min      0.000000   50.000000   16.000000    5.000000   20.000000
# 25%     20.000000   55.000000   17.000000    6.000000   34.000000
# 50%     47.000000   60.000000   18.000000    7.000000   49.000000
# 75%     74.000000   66.000000   19.000000    9.000000   65.000000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       91      70       11        6        50
# 1       58      55       18        8        47
# 3       64      51       13        9        43
# 4       92      54       12        8        63
# 7       63      69       13        8        21
# ..     ...     ...      ...      ...       ...
# 988     97      66       11        5        32
# 989     55      51       10        6        35
# 992     65      64       16        5        36
# 998     82      65       10        7        25
# 999     97      53       19        5        59
#
# [465 rows x 5 columns]

# %%
df1[friend15& grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 1       58      55       18        8        47
# 10      71      56       16        5        28
# 15      62      68       18       10        72
# 17      55      58       19        5        47
# 26      67      50       20        7        32
# ..     ...     ...      ...      ...       ...
# 969     95      66       18        5        39
# 979     91      59       19       10        59
# 985     79      62       17        5        37
# 992     65      64       16        5        36
# 999     97      53       19        5        59
#
# [217 rows x 5 columns]

# %%
df1[friend15 & grade50].count()
# Out:
# grade       217
# weight      217
# friends     217
# cousins     217
# projects    217
# dtype: int64

# %%
df1[friend15& grade50]['weight'].value_counts()
# Out:
# weight
# 55    14
# 70    14
# 58    13
# 65    12
# 61    12
# 52    12
# 51    11
# 67    11
# 56    11
# 62    11
# 69    11
# 50    11
# 64    10
# 57    10
# 54     9
# 66     9
# 68     9
# 59     8
# 60     8
# 63     6
# 53     5
# Name: count, dtype: int64

# %%
df1[friend15 & grade50]. describe()
# Out:
#             grade      weight     friends     cousins    projects
# count  217.000000  217.000000  217.000000  217.000000  217.000000
# mean    76.050691   60.101382   18.142857    7.405530   50.437788
# std     14.612026    6.199526    1.348132    1.653158   17.301173
# min     51.000000   50.000000   16.000000    5.000000   20.000000
# 25%     64.000000   55.000000   17.000000    6.000000   35.000000
# 50%     77.000000   60.000000   18.000000    7.000000   51.000000
# 75%     89.000000   65.000000   19.000000    9.000000   66.000000
# max    100.000000   70.000000   20.000000   10.000000   80.000000

# %%
df1[friend15 & grade50]['friends']
# Out:
# 1      18
# 10     16
# 15     18
# 17     19
# 26     20
#        ..
# 969    18
# 979    19
# 985    17
# 992    16
# 999    19
# Name: friends, Length: 217, dtype: int64

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
matplotlib inline

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='pie')
# Out:
# <Axes: ylabel='projects'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='area')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='line')
# Out:
# <Axes: xlabel='grade'>

# %%
from matplotlib import pyplot as plt

# %%
df1.to_csv('/feb5TestData.csv')

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       91      70       11        6        50
# 1       58      55       18        8        47
# 2       13      53       12        8        77
# 3       64      51       13        9        43
# 4       92      54       12        8        63
# ..     ...     ...      ...      ...       ...
# 995      8      61       15       10        54
# 996      8      55       15        6        35
# 997      3      56       15       10        79
# 998     82      65       10        7        25
# 999     97      53       19        5        59
#
# [1000 rows x 5 columns]

# %%
fdf=[friend15 & grade50]

# %%
fdf
# Out:
# [0      False
#  1       True
#  2      False
#  3      False
#  4      False
#         ...
#  995    False
#  996    False
#  997    False
#  998    False
#  999     True
#  Length: 1000, dtype: bool]

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade50].plot(x='grade',y='projects',kind='bar', title='sample Graph')
# Out:
# <Axes: title={'center': 'sample Graph'}, xlabel='grade'>
