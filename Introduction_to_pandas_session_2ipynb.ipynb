# %% [markdown]
# <a href="https://colab.research.google.com/github/Fatimanridegreeclg/Mini-project-/blob/main/Introduction_to_pandas_session_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive mount('content/drive')
# Out:
# 'content/drive'

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/Credit_Card_Applications.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
dataset.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# ...

# %%
#To read a data cell from a selected row of column
#loc - iloc
#dframe.loc[rows,columnames]
#dataset.loc[[0,1,5],['A11','A2','A1']]]

# %%
#find out single value
dataset.loc[1,'A2']
# Out:
# 22.67

# %%
#change any value
dataset.loc[1,'A2']=23

# %%
dataset.loc[1,'A2']
# Out:
# 23.0

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
  idata={'Age':age,'Height': height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [90,
#   97,
#   89,
#   89,
#   90,
#   20,
#   66,
#   79,
#   62,
#   32,
#   69,
#   65,
#   11,
#   8,
#   40,
#   2,
#   59,
#   76,
#   82,
#   1,
#   98,
#   52,
#   63,
#   2,
#   80,
#   37,
#   77,
#   17,
#   4,
#   89,
#   51,
#   29,
#   90,
#   47,
#   47,
#   8,
#   88,
#   78,
#   73,
#   1,
#   52,
#   51,
#   13,
#   30,
#   36,
#   40,
#   75,
#   69,
#   2,
#   25,
#   62,
#   61,
#   38,
#   9,
#   19,
#   36,
#   50,
#   39,
#   46,
#   0,
#   55,
#   69,
#   71,
#   24,
#   68,
#   60,
#   39,
#   43,
#   92,
#   10,
#   70,
#   31,
#   100,
#   82,
#   53,
#   82,
#   2,
#   39,
#   65,
#   60,
#   5,
#   64,
#   94,
#   83,
#   20,
#   64,
#   72,
#   92,
#   44,
#   12,
#   13,
#   34,
#   77,
#   45,
#   25,
#   82,
#   100,
#   80,
#   96,
#   33],
#  'Height': [10,
#   0,
#   74,
#   54,
#   78,
#   65,
#   14,
#   96,
#   4,
#   57,
#   59,
#   84,
#   0,
#   35,
#   1,
#   1,
#   61,
#   87,
#   91,
#   51,
#   50,
#   79,
#   57,
#   13,
# ...

# %%
df1=pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    90      10      83     43
# 1    97       0      26      4
# 2    89      74      44      6
# 3    89      54      48     21
# 4    90      78      96     63
# ..  ...     ...     ...    ...
# 95   82      48      15     62
# 96  100      15      74     50
# 97   80      64      89     69
# 98   96      74       2     20
# 99   33      88      62     67
#
# [100 rows x 4 columns]

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    51.610000   52.850000   44.110000   49.890000
# std     29.593507   29.115366   30.144733   31.208292
# min      0.000000    0.000000    2.000000    0.000000
# 25%     29.750000   32.500000   15.750000   18.750000
# 50%     52.500000   54.500000   40.500000   51.000000
# 75%     77.000000   78.250000   74.000000   78.250000
# max    100.000000  100.000000  100.000000   99.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    90      10
# 1    97       0
# 2    89      74
# 3    89      54
# 4    90      78
# ..  ...     ...
# 95   82      48
# 96  100      15
# 97   80      64
# 98   96      74
# 99   33      88
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   90      10
# 3   89      54

# %%
df2=df1[['Age','Height']]

# %%
df2
# Out:
#     Age  Height
# 0    90      10
# 1    97       0
# 2    89      74
# 3    89      54
# 4    90      78
# ..  ...     ...
# 95   82      48
# 96  100      15
# 97   80      64
# 98   96      74
# 99   33      88
#
# [100 rows x 2 columns]

# %%
df2.describe()
# Out:
#               Age      Height
# count  100.000000  100.000000
# mean    51.610000   52.850000
# std     29.593507   29.115366
# min      0.000000    0.000000
# 25%     29.750000   32.500000
# 50%     52.500000   54.500000
# 75%     77.000000   78.250000
# max    100.000000  100.000000

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    90      10      83     43
# 1    97       0      26      4
# 2    89      74      44      6
# 3    89      54      48     21
# 4    90      78      96     63
# ..  ...     ...     ...    ...
# 95   82      48      15     62
# 96  100      15      74     50
# 97   80      64      89     69
# 98   96      74       2     20
# 99   33      88      62     67
#
# [100 rows x 4 columns]
